# %%
import os
import pandas as pd
import tiktoken
from graphrag.query.indexer_adapters import read_indexer_entities, read_indexer_reports
from graphrag.query.llm.oai.chat_openai import ChatOpenAI
from graphrag.query.llm.oai.typing import OpenaiApiType
from graphrag.query.structured_search.global_search.community_context import (
    GlobalCommunityContext,
)
from graphrag.query.structured_search.global_search.search import GlobalSearch
import subprocess
import io
import sys
import util
import prompt_template
from openai import OpenAI
import re
import api

# %%
#remove uncommon characters 
def clean_text_file(input_file, output_file):
    with open(input_file, 'r', encoding='utf-8', errors='ignore') as file:
        content = file.read()
    
    cleaned_content = ''.join(char for char in content if ord(char) < 128)
    
    with open(output_file, 'w', encoding='utf-8') as file:
        file.write(cleaned_content)
input_file = "input/articles.txt"
#clean_text_file(input_file, input_file)

# %%
def run_graphrag_index():
    try:
        subprocess.run([sys.executable, "-m", "graphrag.index", "--root", "."], 
                                capture_output=False, text=True, check=True)
        print("Command executed successfully.")
    except subprocess.CalledProcessError as e:
        print("An error occurred while running the command:")
        print("Error output:", e.stderr)
    except FileNotFoundError:
        print("Error: graphrag module not found. Make sure it's installed and in your Python path.")

#run_graphrag_index()

# %%
report_df = pd.read_parquet(f"GPT-4-turbo-indexing/artifacts/create_final_community_reports.parquet")
report_df
# Out:
#   community                                       full_content  level  rank  \
# 0         0  # Regulatory Compliance and Relationships in t...      0   7.5
# 1         1  # Regulatory and Operational Dynamics in the T...      0   8.5
# 2         2  # Regulatory Framework in Financial Trading\n\...      0   8.5
# 3         3  # Online Trading Ecosystem Analysis\n\nThis re...      0   7.5
#
#                                                title  \
# 0  Regulatory Compliance and Relationships in the...
# 1  Regulatory and Operational Dynamics in the Tra...
# 2          Regulatory Framework in Financial Trading
# 3                  Online Trading Ecosystem Analysis
#
#                                     rank_explanation  \
# 0  The impact severity rating is high due to the ...
# 1  The high impact severity rating reflects the c...
# 2  The high impact severity rating reflects the c...
# 3  The impact severity rating is relatively high ...
#
#                                              summary  \
# 0  This report examines the intricate network of ...
# 1  This report delves into the intricate network ...
# 2  This report outlines the intricate relationshi...
# 3  This report delves into the structured relatio...
#
#                                             findings  \
# 0  [{'explanation': 'Brokers, including broker/de...
# 1  [{'explanation': 'Broker/Dealers occupy a cent...
# 2  [{'explanation': 'The Organization is at the h...
# 3  [{'explanation': 'Customers, both individuals ...
#
#                                    full_content_json  \
# 0  {\n    "title": "Regulatory Compliance and Rel...
# 1  {\n    "title": "Regulatory and Operational Dy...
# 2  {\n    "title": "Regulatory Framework in Finan...
# 3  {\n    "title": "Online Trading Ecosystem Anal...
#
#                                      id
# 0  1abd8f20-01b6-4cb5-8dee-eee69fa31ce3
# 1  e451bdd5-b8b0-48c3-8ab1-8505357d9ee7
# 2  b7cd43b6-8cd2-4578-8702-cf96dda0890b
# 3  0675a3fe-2a43-4f12-9e4f-7ffac697454a

# %%
report_df = pd.read_parquet(f"GPT-4o-mini-indexing/artifacts/create_final_community_reports.parquet")
report_df
# Out:
#    community                                       full_content  level  rank  \
# 0         66  # Organization and Information Security Manage...      2   8.5
# 1         67  # Information Security Competence and Awarenes...      2   7.5
# 2         68  # Information Systems and Records Management\n...      2   7.5
# 3         69  # Information Security Management System Commu...      2   8.0
# 4         70  # Information Security Management System and S...      2   7.5
# ..       ...                                                ...    ...   ...
# 62         5  # Brokerage and Trading Community\n\nThe commu...      0   8.5
# 63         6  # Information Security Incident Management Com...      0   7.5
# 64         7  # Information Security Management Community\n\...      0   7.5
# 65         8  # Information Security Community\n\nThe Inform...      0   8.5
# 66         9  # Financial Regulatory Community: Exchange and...      0   8.5
#
#                                                 title  \
# 0    Organization and Information Security Management
# 1       Information Security Competence and Awareness
# 2          Information Systems and Records Management
# 3    Information Security Management System Community
# 4   Information Security Management System and Sta...
# ..                                                ...
# 62                    Brokerage and Trading Community
# 63  Information Security Incident Management Commu...
# 64          Information Security Management Community
# 65                     Information Security Community
# 66  Financial Regulatory Community: Exchange and B...
#
#                                      rank_explanation  \
# 0   The impact severity rating is high due to the ...
# 1   The impact severity rating is high due to the ...
# 2   The impact severity rating is high due to the ...
# 3   The impact severity rating is high due to the ...
# 4   The impact severity rating is high due to the ...
# ..                                                ...
# 62  The impact severity rating is high due to the ...
# 63  The impact severity rating is high due to the ...
# 64  The impact severity rating is high due to the ...
# 65  The impact severity rating is high due to the ...
# 66  The impact severity rating is high due to the ...
#
#                                               summary  \
# 0   The community centers around the concept of an...
# 1   This community focuses on the critical aspects...
# 2   The community focuses on the relationship betw...
# 3   The community is centered around the Informati...
# 4   The community focuses on the Information Secur...
# ..                                                ...
# 62  The community encompasses various entities inv...
# 63  The community focuses on the management of inf...
# 64  The community focuses on information security ...
# 65  The Information Security Community comprises v...
# 66  The community is centered around the Exchange,...
#
#                                              findings  \
# 0   [{'explanation': 'Organizations are pivotal in...
# 1   [{'explanation': 'Competence is a fundamental ...
# 2   [{'explanation': 'Information systems are esse...
# 3   [{'explanation': 'The Information Security Man...
# 4   [{'explanation': 'Interested Parties play a cr...
# ..                                                ...
# 62  [{'explanation': 'Brokers serve as essential i...
# 63  [{'explanation': 'Information Security Inciden...
# 64  [{'explanation': 'Information Classification i...
# 65  [{'explanation': 'Information security is the ...
# 66  [{'explanation': 'The Exchange serves as a piv...
#
#                                     full_content_json  \
# 0   {\n    "title": "Organization and Information ...
# 1   {\n    "title": "Information Security Competen...
# 2   {\n    "title": "Information Systems and Recor...
# 3   {\n    "title": "Information Security Manageme...
# 4   {\n    "title": "Information Security Manageme...
# ..                                                ...
# 62  {\n    "title": "Brokerage and Trading Communi...
# 63  {\n    "title": "Information Security Incident...
# 64  {\n    "title": "Information Security Manageme...
# 65  {\n    "title": "Information Security Communit...
# 66  {\n    "title": "Financial Regulatory Communit...
#
#                                       id
# 0   9a3533a6-0cc3-4fb6-9662-18e6766262fb
# 1   e94da1ed-34fb-4a9d-be5f-f86c56b030c3
# 2   c03614a3-841c-42dc-b079-30c2da132c38
# 3   0bdc5f02-ea5b-4137-9fa9-c26029978f77
# 4   4f21a029-e29c-4193-b1ed-6c986c6a9fb0
# ..                                   ...
# 62  c5a7b791-3cb2-4797-ad31-cc1b2eb394c5
# 63  fb1dcec7-17bf-44f3-8684-323d99f9e70e
# 64  37120226-8608-4358-a1c5-7afecbbeac48
# 65  41e6583c-fa02-4c8a-aa60-3727de7ba229
# 66  8c358e28-c59f-4dd1-a75c-46501bd18444
#
# [67 rows x 10 columns]

# %%
api_key = os.environ["GRAPHRAG_API_KEY"]
llm_model = "gpt-4o-mini-2024-07-18"

llm = ChatOpenAI(
    api_key=api_key,
    model=llm_model,
    api_type=OpenaiApiType.OpenAI,  
    max_retries=20,
)

token_encoder = tiktoken.get_encoding("cl100k_base")

# %%
INPUT_DIR = "./GPT-4o-mini-indexing/artifacts"
COMMUNITY_REPORT_TABLE = "create_final_community_reports"
ENTITY_TABLE = "create_final_nodes"
ENTITY_EMBEDDING_TABLE = "create_final_entities"
COMMUNITY_LEVEL = 2

# %%
entity_df = pd.read_parquet(f"{INPUT_DIR}/{ENTITY_TABLE}.parquet")
report_df = pd.read_parquet(f"{INPUT_DIR}/{COMMUNITY_REPORT_TABLE}.parquet")
entity_embedding_df = pd.read_parquet(f"{INPUT_DIR}/{ENTITY_EMBEDDING_TABLE}.parquet")

reports = read_indexer_reports(report_df, entity_df, COMMUNITY_LEVEL)
entities = read_indexer_entities(entity_df, entity_embedding_df, COMMUNITY_LEVEL)
print(f"Report records: {len(report_df)}")
report_df.head()
# Out:
# Report records: 67
#   community                                       full_content  level  rank  \
# 0        66  # Organization and Information Security Manage...      2   8.5
# 1        67  # Information Security Competence and Awarenes...      2   7.5
# 2        68  # Information Systems and Records Management\n...      2   7.5
# 3        69  # Information Security Management System Commu...      2   8.0
# 4        70  # Information Security Management System and S...      2   7.5
#
#                                                title  \
# 0   Organization and Information Security Management
# 1      Information Security Competence and Awareness
# 2         Information Systems and Records Management
# 3   Information Security Management System Community
# 4  Information Security Management System and Sta...
#
#                                     rank_explanation  \
# 0  The impact severity rating is high due to the ...
# 1  The impact severity rating is high due to the ...
# 2  The impact severity rating is high due to the ...
# 3  The impact severity rating is high due to the ...
# 4  The impact severity rating is high due to the ...
#
#                                              summary  \
# 0  The community centers around the concept of an...
# 1  This community focuses on the critical aspects...
# 2  The community focuses on the relationship betw...
# 3  The community is centered around the Informati...
# 4  The community focuses on the Information Secur...
#
#                                             findings  \
# 0  [{'explanation': 'Organizations are pivotal in...
# 1  [{'explanation': 'Competence is a fundamental ...
# 2  [{'explanation': 'Information systems are esse...
# 3  [{'explanation': 'The Information Security Man...
# 4  [{'explanation': 'Interested Parties play a cr...
#
#                                    full_content_json  \
# 0  {\n    "title": "Organization and Information ...
# 1  {\n    "title": "Information Security Competen...
# 2  {\n    "title": "Information Systems and Recor...
# 3  {\n    "title": "Information Security Manageme...
# 4  {\n    "title": "Information Security Manageme...
#
#                                      id
# 0  9a3533a6-0cc3-4fb6-9662-18e6766262fb
# 1  e94da1ed-34fb-4a9d-be5f-f86c56b030c3
# 2  c03614a3-841c-42dc-b079-30c2da132c38
# 3  0bdc5f02-ea5b-4137-9fa9-c26029978f77
# 4  4f21a029-e29c-4193-b1ed-6c986c6a9fb0

# %%
context_builder = GlobalCommunityContext(
    community_reports=reports,
    entities=entities,
    token_encoder=token_encoder,
)

# %%
context_builder_params = {
    "use_community_summary": False,  # False means using full community reports. True means using community short summaries.
    "shuffle_data": True,
    "include_community_rank": True,
    "min_community_rank": 0,
    "community_rank_name": "rank",
    "include_community_weight": True,
    "community_weight_name": "occurrence weight",
    "normalize_community_weight": True,
    "max_tokens": 5000,
    "context_name": "Reports",
}

map_llm_params = {
    "max_tokens": 1000,
    "temperature": 0.0,
    "response_format": {"type": "json_object"},
}

reduce_llm_params = {
    "max_tokens": 1000, 
    "temperature": 0.0,
}

# %%
search_engine = GlobalSearch(
    llm=llm,
    context_builder=context_builder,
    token_encoder=token_encoder,
    max_data_tokens=5000, 
    map_llm_params=map_llm_params,
    reduce_llm_params=reduce_llm_params,
    allow_general_knowledge=False,  # set this to True will add instruction to encourage the LLM to incorporate general knowledge in the response, which may increase hallucinations, but could be useful in some use cases.
    json_mode=False,  # set this to False if your LLM model does not support JSON mode.
    context_builder_params=context_builder_params,
    concurrent_coroutines=32,
    response_type="multiple paragraphs",
)

# %%
#Report utils
num_of_LLM_calls = 0
num_of_comp_violations = 0
num_of_part_violations = 0
num_of_compliances = 0
num_of_self_redundencies = 0
num_of_redundencies = 0
num_of_self_conflicts = 0
num_of_conflicts = 0

# %%
results = []
with open("documents/requirements/FR/req_1.txt", mode="r", encoding="utf-8") as req_file:
    req_content = req_file.read()
    result = await search_engine.asearch(f"I want you to find all the entities that can be related to {req_content}.")
    num_of_LLM_calls += result.llm_calls
    results.append(result)
# Out:
# ##DEBUG##: {
#     "points": [
#         {"description": "The process of logging out of the system involves user engagement with the account management features, which is crucial for maintaining security and user control over their accounts. This engagement is essential for ensuring that users can manage their access effectively [Data: Reports (33)]", "score": 70},
#         {"description": "Error handling during the logout process is important as it ensures that users are informed of any issues that may arise, thereby enhancing user experience and trust in the system. Displaying appropriate error messages is a critical aspect of user interface design [Data: Reports (33)]", "score": 60}
#     ]
# }
# ##DEBUG##: {
#     "points": [
#         {"description": "The process of logging out of the system involves user interactions with the Account Maintenance Page, which serves as a central hub for managing account settings, including the logout option. This relationship emphasizes the importance of user experience in account management [Data: Reports (74)]", "score": 70},
#         {"description": "Error handling during the logout process is crucial, as it requires displaying an appropriate error message if there is an issue during logout. This aspect highlights the need for effective communication with users to ensure a smooth experience [Data: Reports (73)]", "score": 60}
#     ]
# }
# ##DEBUG##: {
#     "points": [
#         {"description": "The process of logging out of the system involves user interaction with the 'Logout' option, which is a critical step in ensuring account security and user session management. This process is essential for protecting user data and maintaining the integrity of the system [Data: Reports (75, 78, 71, 53, 18)].", "score": 80},
#         {"description": "Error handling during the logout process is crucial, as it ensures that users receive appropriate feedback if an issue occurs. This aspect of the logout functionality is important for user experience and system reliability [Data: Reports (75, 78, 71, 53, 18)].", "score": 70}
#     ]
# }
# ##DEBUG##: {
#     "points": [
#         {"description": "The login process is a critical step for users to access the system and manage their stock transactions. It involves verifying user credentials against the information stored in the database, ensuring that only authorized users can access sensitive data. The security of the login process is paramount, as any vulnerabilities could lead to unauthorized access and potential data breaches. This aspect of the community underscores the need for strong authentication mechanisms to protect user information and maintain trust in the system. [Data: Reports (29)]", "score": 80},
#         {"description": "The database serves as a critical component of the system, managing a variety of data types essential for operational efficiency. It stores user information, which is vital for the system's functionality. The database's ability to securely store user credentials, including usernames and passwords, is crucial for authentication processes. Regular queries to the database ensure that users receive up-to-date information, enhancing the overall responsiveness of the system. [Data: Reports (29)]", "score": 70},
#         {"description": "The Secure Development Policy emphasizes the need for security measures to be integrated at every stage of development, including the logout functionality. This policy aims to mitigate risks associated with software vulnerabilities and enhance the overall security posture of the organization. [Data: Reports (50)]", "score": 60},
#         {"description": "Technical Review involves assessing business-critical applications after changes to ensure they function correctly and securely. This process is essential for identifying potential security issues in the logout functionality before they can be exploited. [Data: Reports (50)]", "score": 60}
#     ]
# }
# ##DEBUG##: {
#     "points": [
#         {"description": "The process of logging out of the system involves user interaction with the interface, specifically selecting the 'Logout' option, which is a critical step in ensuring the security of user accounts. This process is essential for maintaining user privacy and preventing unauthorized access to accounts [Data: Reports (69, 40, 49, 79, 44, +more)].", "score": 80},
#         {"description": "Error handling during the logout process is crucial, as it ensures that users receive appropriate feedback if an issue occurs while attempting to log out. This aspect of the process is important for user experience and trust in the system [Data: Reports (69, 40, 49, 79, 44, +more)].", "score": 70}
#     ]
# }
# ##DEBUG##: {
#     "points": [
#         {"description": "The user is the primary entity involved in the logout process, as they initiate the action by selecting the 'Logout' option. This highlights the user's role in managing their account and ensuring their session is securely terminated [Data: Reports (72)].", "score": 80},
#         {"description": "The system is the entity that processes the logout request, ensuring that the user is logged out and redirected to the main page. This functionality is crucial for maintaining security and user experience [Data: Reports (72)].", "score": 80},
#         {"description": "Error handling is an important aspect of the logout process, as it involves displaying an appropriate error message if there is an issue during logout. This ensures that users are informed of any problems and can take necessary actions [Data: Reports (72)].", "score": 70}
#     ]
# }
# # Entities Related to Logging Out of the System
#
# The process of logging out of the system involves several key entities and interactions that are crucial for ensuring user security and experience. Below is a comprehensive overview of these entities based on the analysis of the logout process.
#
# ## User Interaction
#
# The user is the primary entity involved in the logout process. They initiate the action by selecting the "Logout" option, which is essential for managing their account and ensuring that their session is securely terminated. This interaction emphasizes the user's role in maintaining their account security [Data: Reports (72)].
#
# ## System Functionality
#
# The system itself plays a critical role in processing the logout request. Upon the user's selection of the "Logout" option, the system ensures that the user is logged out and subsequently redirected to the main page. This functionality is vital for maintaining both security and a positive user experience [Data: Reports (72)].
#
# ## Account Management
#
# The logout process is closely tied to the Account Maintenance Page, which serves as a central hub for managing account settings, including the logout option. This relationship highlights the importance of user experience in account management and the need for intuitive navigation [Data: Reports (74)].
#
# ## Error Handling
#
# Error handling is a significant aspect of the logout process. It ensures that users receive appropriate feedback if an issue occurs during logout. Displaying an error message when problems arise is crucial for user experience and trust in the system [Data: Reports (75, 78, 71, 53, 18)]. Effective communication with users regarding any issues enhances their overall experience and confidence in the system [Data: Reports (73)].
#
# ## Security Measures
#
# The logout functionality is also governed by security measures that are integrated throughout the system. This includes the Secure Development Policy, which emphasizes the need for security at every stage of development, including the logout process. Such measures are essential for mitigating risks associated with software vulnerabilities [Data: Reports (50)].
#
# ## Conclusion
#
# In summary, the entities related to logging out of the system include the user, the system's functionality, account management features, error handling mechanisms, and overarching security measures. Each of these components plays a vital role in ensuring a secure and user-friendly logout experience. The interplay between these entities is crucial for maintaining user trust and safeguarding sensitive information [Data: Reports (29, 50)].

# %%
df = pd.DataFrame(results[0].context_data['reports'])
context_df = df.sort_values(by='occurrence weight', ascending=False) 


filtered_df = context_df[context_df['occurrence weight'] > 0.6]
result_str = '\n'.join(filtered_df['content'])
content_context = context_df["content"][0] + "\n" + result_str

print(content_context)
context_df.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.DataFrame(result.context_data['reports'])
#       3 context_df = df.sort_values(by='occurrence weight', ascending=False)
#       4 content_context = context_df["content"][0]
#
# NameError: name 'result' is not defined

# %%
sample_string = ""
for resp in result.map_responses:
    sample_string += str(resp)

pattern = re.compile(r"'answer':\s*'(.*?)',\s*'score':\s*(\d+)")
matches = pattern.findall(sample_string)

df = pd.DataFrame(matches, columns=['Answer', 'Score'])
df['Score'] = pd.to_numeric(df['Score'])
sorted_df = df.sort_values(by='Score', ascending=False) 

filtered_df = df[df['Score'] >= 0.7]
result_str = '\n'.join(filtered_df['Answer'])
content_context = content_context + "\n" + result_str

sorted_df
# Out:
#                                                Answer  Score
# 6   The system is the entity that processes the lo...     80
# 8   The login process is a critical step for users...     80
# 0   The process of logging out of the system invol...     70
# 2   The process of logging out of the system invol...     70
# 4   Error handling during the logout process is cr...     70
# 5   Error handling during the logout process is cr...     70
# 7   Error handling is an important aspect of the l...     70
# 1   Error handling during the logout process is cr...     60
# 3   Error handling during the logout process is im...     60
# 9   The Secure Development Policy emphasizes the n...     60
# 10  Technical Review involves assessing business-c...     60

# %%
# call GPT-4o
def call_LLM(user_prompt, system_prompt):
    client = OpenAI(api_key=api.API_KEY)
    response = client.chat.completions.create(
        model="gpt-4o-mini-2024-07-18", 
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        #max_tokens = 4096,  
        temperature = 0.2
    )
    global num_of_LLM_calls
    num_of_LLM_calls += 1
    return response

# %%
# like GPT4o.ipynb but system prompt is the reduced content
